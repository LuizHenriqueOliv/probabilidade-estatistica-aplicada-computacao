# %% [markdown]
# Análise De Dados Com Python No Curso De Probabilidade e Estatística

# %%
import pandas as pd
from random import choices

df = pd.read_csv('dataset/student-mat.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.shape
# Out:
# (395, 33)

# %%
df["Mjob"]
# Out:
# 0       at_home
# 1       at_home
# 2       at_home
# 3        health
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393    services
# 394       other
# Name: Mjob, Length: 395, dtype: object

# %%
df[["Mjob", "age"]]
# Out:
#          Mjob  age
# 0     at_home   18
# 1     at_home   17
# 2     at_home   15
# 3      health   15
# 4       other   16
# ..        ...  ...
# 390  services   20
# 391  services   17
# 392     other   21
# 393  services   18
# 394     other   19
#
# [395 rows x 2 columns]

# %%
df[df["age"] > 20]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1 G2 G3
# 247  ...      5        4      5     5     5      1       16   6  8  8
# 392  ...      5        5      3     3     3      3        3  10  8  7
#
# [2 rows x 33 columns]

# %%
df["irmaos"] = choices(range(1, 11), k = 395)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.rename(columns={"irmaos": "siblings"})
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.sort_values("age")
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 36      GP   M   15       U     LE3       T     4     3   teacher  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 306     GP   M   20       U     GT3       A     3     2  services     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 247     GP   M   22       U     GT3       T     3     1  services  services
#
# ...

# %%
df["age"].mean()
# Out:
# np.float64(16.696202531645568)

# %%
df["age"].max()
# Out:
# np.int64(22)

# %%
df["age"].min()
# Out:
# np.int64(15)

# %%
df["age"].value_counts()
# Out:
# age
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: count, dtype: int64
